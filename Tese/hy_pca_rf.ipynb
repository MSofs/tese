# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from tqdm import tqdm
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectPercentile, f_classif

import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA

# %%
import pickle
with open('variaveis.pkl', 'rb') as f:
  X_train, Y_train, X_test, Y_teste = pickle.load(f)

# %%
pipe = Pipeline([('pca', PCA()),
                 ('rf', RandomForestClassifier())])

# Setting up the parameters for the grid search
param_grid = {'pca__n_components': [2, 3,5],
              'rf__n_estimators': [50, 100, 150],
              'rf__max_depth': [5, 10]}

# Running the grid search
grid = GridSearchCV(pipe, param_grid=param_grid, cv=5, verbose=10)
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START pca__n_components=2, rf__max_depth=5, rf__n_estimators=50..
# [CV 1/5; 1/18] END pca__n_components=2, rf__max_depth=5, rf__n_estimators=50;, score=0.757 total time=   0.0s
# [CV 2/5; 1/18] START pca__n_components=2, rf__max_depth=5, rf__n_estimators=50..
# [CV 2/5; 1/18] END pca__n_components=2, rf__max_depth=5, rf__n_estimators=50;, score=0.815 total time=   0.0s
# [CV 3/5; 1/18] START pca__n_components=2, rf__max_depth=5, rf__n_estimators=50..
# [CV 3/5; 1/18] END pca__n_components=2, rf__max_depth=5, rf__n_estimators=50;, score=0.770 total time=   0.0s
# [CV 4/5; 1/18] START pca__n_components=2, rf__max_depth=5, rf__n_estimators=50..
# [CV 4/5; 1/18] END pca__n_components=2, rf__max_depth=5, rf__n_estimators=50;, score=0.778 total time=   0.0s
# [CV 5/5; 1/18] START pca__n_components=2, rf__max_depth=5, rf__n_estimators=50..
# ...

# %%
# Printing the best parameters and the corresponding accuracy score
print("Best parameters:", grid.best_params_)
print("Accuracy score:", grid.best_score_)
# Out:
# Best parameters: {'pca__n_components': 5, 'rf__max_depth': 10, 'rf__n_estimators': 150}
# Accuracy score: 0.9556100217864925

# %%
pecc_dt = cross_val_score(grid,  X_train, Y_train, cv = 10).mean()  # ...,X_pca,...
pecc_dt
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START pca__n_components=2, rf__max_depth=5, rf__n_estimators=50..
# [CV 1/5; 1/18] END pca__n_components=2, rf__max_depth=5, rf__n_estimators=50;, score=0.746 total time=   0.0s
# [CV 2/5; 1/18] START pca__n_components=2, rf__max_depth=5, rf__n_estimators=50..
# [CV 2/5; 1/18] END pca__n_components=2, rf__max_depth=5, rf__n_estimators=50;, score=0.803 total time=   0.0s
# [CV 3/5; 1/18] START pca__n_components=2, rf__max_depth=5, rf__n_estimators=50..
# [CV 3/5; 1/18] END pca__n_components=2, rf__max_depth=5, rf__n_estimators=50;, score=0.754 total time=   0.0s
# [CV 4/5; 1/18] START pca__n_components=2, rf__max_depth=5, rf__n_estimators=50..
# [CV 4/5; 1/18] END pca__n_components=2, rf__max_depth=5, rf__n_estimators=50;, score=0.785 total time=   0.0s
# [CV 5/5; 1/18] START pca__n_components=2, rf__max_depth=5, rf__n_estimators=50..
# ...
